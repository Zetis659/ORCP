# %% [markdown]
# # Импорт библиотек

# %%
import pandas as pd
import os
pd.set_option('display.max_rows', None)  # Показывать все строки
pd.set_option('display.max_columns', None)  # Показывать все столбцы

# %% [markdown]
# # Загрузка датасета

# %%
# Получите текущий каталог блокнота Jupyter
current_dir = os.getcwd()

# Сформируйте путь к файлу CSV относительно текущего каталога
csv_path = os.path.join(current_dir, '../SRC/Parsing/Results/Data/all_cars.csv')

# %%
df = pd.read_csv(csv_path)

# %%
df.shape
# Out:
# (376094, 39)

# %%
df.head()
# Out:
#         brand   model  year    generation engine_type       drive_type  \
# 0  LADA (ВАЗ)  Granta  2018  I Рестайлинг    GASOLINE  FORWARD_CONTROL
# 1  LADA (ВАЗ)  Granta  2018  I Рестайлинг    GASOLINE  FORWARD_CONTROL
# 2  LADA (ВАЗ)  Granta  2018  I Рестайлинг    GASOLINE  FORWARD_CONTROL
# 3  LADA (ВАЗ)  Granta  2018  I Рестайлинг    GASOLINE  FORWARD_CONTROL
# 4  LADA (ВАЗ)  Granta  2018  I Рестайлинг    GASOLINE  FORWARD_CONTROL
#
#   transmission  engine_capacity_liters  engine_capacity_cubic  engine_power  \
# 0   MECHANICAL                     1.6                   1596            87
# 1   MECHANICAL                     1.6                   1596            87
# 2   MECHANICAL                     1.6                   1596            87
# 3   MECHANICAL                     1.6                   1596            87
# 4        ROBOT                     1.6                   1596           106
#
#    ... owners       pts days_on_sale      seller price_segment  start_sales  \
# ...

# %% [markdown]
# # Краткая информация

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 376094 entries, 0 to 376093
# Data columns (total 39 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   brand                   376094 non-null  object
#  1   model                   376094 non-null  object
#  2   year                    376094 non-null  int64
#  3   generation              300889 non-null  object
#  4   engine_type             376094 non-null  object
#  5   drive_type              376094 non-null  object
#  6   transmission            376094 non-null  object
#  7   engine_capacity_liters  376094 non-null  float64
#  8   engine_capacity_cubic   376094 non-null  int64
#  9   engine_power            376094 non-null  int64
#  10  availability            376088 non-null  object
#  11  mileage                 376094 non-null  int64
#  12  color                   376094 non-null  object
#  13  car_type                376094 non-null  object
# ...

# %% [markdown]
# # Пропущенные значения

# %%
df.isna().mean().sort_values(ascending=False)
# Out:
# end_sales                 0.308215
# trunk_volume              0.225196
# generation                0.199963
# price_pred_from           0.131246
# price_pred_to             0.131108
# acceleration              0.087882
# clearance                 0.025712
# pts                       0.022393
# tax                       0.018463
# car_class                 0.003435
# availability              0.000016
# doors_count               0.000000
# owners                    0.000000
# customs_cleared           0.000000
# vendor                    0.000000
# days_on_sale              0.000000
# seller                    0.000000
# steering_wheel            0.000000
# price_segment             0.000000
# start_sales               0.000000
# brand                     0.000000
# region                    0.000000
# body_type                 0.000000
# engine_power              0.000000
# year                      0.000000
# engine_type               0.000000
# drive_type                0.000000
# ...

# %%
df.isna().mean().mean()
# Out:
# 0.029580302687557784

# %% [markdown]
# # Дубликаты

# %%
df.duplicated().sum()
# Out:
# 279078

# %%
df_wd = df.drop_duplicates()

# %%
df_wd.shape
# Out:
# (97016, 39)

# %%
df_wd.isna().mean().sort_values(ascending=False)
# Out:
# end_sales                 0.251866
# trunk_volume              0.246660
# generation                0.141492
# price_pred_from           0.134699
# price_pred_to             0.134596
# acceleration              0.122299
# tax                       0.028006
# clearance                 0.021120
# pts                       0.018461
# car_class                 0.006741
# availability              0.000031
# doors_count               0.000000
# owners                    0.000000
# customs_cleared           0.000000
# vendor                    0.000000
# days_on_sale              0.000000
# seller                    0.000000
# steering_wheel            0.000000
# price_segment             0.000000
# start_sales               0.000000
# brand                     0.000000
# region                    0.000000
# body_type                 0.000000
# engine_power              0.000000
# year                      0.000000
# engine_type               0.000000
# drive_type                0.000000
# ...

# %% [markdown]
# # Числовые переменные

# %%
df.describe()
# Out:
#                 year  engine_capacity_liters  engine_capacity_cubic  \
# count  376094.000000           376094.000000          376094.000000
# mean     2011.380700                2.018614            2011.240956
# std        10.323143                0.836595             833.485245
# min      1927.000000                0.000000               0.000000
# 25%      2006.000000                1.500000            1499.000000
# 50%      2013.000000                1.700000            1690.000000
# 75%      2020.000000                2.200000            2199.000000
# max      2023.000000                8.400000            8382.000000
#
#         engine_power         mileage         price     prise_usd  \
# count  376094.000000   376094.000000  3.760940e+05  3.760940e+05
# mean      162.081716   132404.060921  1.974538e+06  2.156318e+04
# std        92.321936   111752.023754  3.322376e+06  3.627345e+04
# min        19.000000        0.000000  1.800000e+04  1.970000e+02
# ...

# %%
df.describe().T
# Out:
#                            count          mean           std      min  \
# year                    376094.0  2.011381e+03  1.032314e+01   1927.0
# engine_capacity_liters  376094.0  2.018614e+00  8.365952e-01      0.0
# engine_capacity_cubic   376094.0  2.011241e+03  8.334852e+02      0.0
# engine_power            376094.0  1.620817e+02  9.232194e+01     19.0
# mileage                 376094.0  1.324041e+05  1.117520e+05      0.0
# price                   376094.0  1.974538e+06  3.322376e+06  18000.0
# prise_usd               376094.0  2.156318e+04  3.627345e+04    197.0
# price_euro              376094.0  1.956795e+04  3.291336e+04    178.0
# tax                     369150.0  9.952413e+03  1.850672e+04      0.0
# doors_count             376094.0  4.536882e+00  6.488795e-01      0.0
# trunk_volume            291399.0  5.034361e+02  2.986901e+02     63.0
# clearance               366424.0  1.738604e+02  2.929049e+01     79.0
# ...

# %%
df_wd.describe()
# Out:
#                year  engine_capacity_liters  engine_capacity_cubic  \
# count  97016.000000            97016.000000           97016.000000
# mean    2010.642719                2.105838            2098.643141
# std       10.192381                0.980899             977.908413
# min     1927.000000                0.000000               0.000000
# 25%     2005.000000                1.600000            1590.000000
# 50%     2012.000000                1.800000            1797.000000
# 75%     2019.000000                2.400000            2405.000000
# max     2023.000000                8.400000            8382.000000
#
#        engine_power         mileage         price     prise_usd    price_euro  \
# count  97016.000000    97016.000000  9.701600e+04  9.701600e+04  9.701600e+04
# mean     166.859817   147527.677641  1.941549e+06  2.121097e+04  1.925169e+04
# std      104.292123   117925.391812  4.907612e+06  5.358025e+04  4.861670e+04
# ...

# %%
df_wd.describe().T
# Out:
#                           count          mean           std      min  \
# year                    97016.0  2.010643e+03  1.019238e+01   1927.0
# engine_capacity_liters  97016.0  2.105838e+00  9.808990e-01      0.0
# engine_capacity_cubic   97016.0  2.098643e+03  9.779084e+02      0.0
# engine_power            97016.0  1.668598e+02  1.042921e+02     19.0
# mileage                 97016.0  1.475277e+05  1.179254e+05      0.0
# price                   97016.0  1.941549e+06  4.907612e+06  18000.0
# prise_usd               97016.0  2.121097e+04  5.358025e+04    197.0
# price_euro              97016.0  1.925169e+04  4.861670e+04    178.0
# tax                     94299.0  1.133629e+04  2.334932e+04      0.0
# doors_count             97016.0  4.473128e+00  7.420485e-01      0.0
# trunk_volume            73086.0  5.175108e+02  3.800663e+02     63.0
# clearance               94967.0  1.681172e+02  3.004764e+01     79.0
# acceleration            85151.0  1.072609e+01  3.421404e+00      2.1
# ...

# %% [markdown]
# ## Категориальные переменные

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 376094 entries, 0 to 376093
# Data columns (total 39 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   brand                   376094 non-null  object
#  1   model                   376094 non-null  object
#  2   year                    376094 non-null  int64
#  3   generation              300889 non-null  object
#  4   engine_type             376094 non-null  object
#  5   drive_type              376094 non-null  object
#  6   transmission            376094 non-null  object
#  7   engine_capacity_liters  376094 non-null  float64
#  8   engine_capacity_cubic   376094 non-null  int64
#  9   engine_power            376094 non-null  int64
#  10  availability            376088 non-null  object
#  11  mileage                 376094 non-null  int64
#  12  color                   376094 non-null  object
#  13  car_type                376094 non-null  object
# ...

# %%
df.describe(include='object').T
# Out:
#                  count unique                   top    freq
# brand           376094     89            LADA (ВАЗ)   53673
# model           376094   1763                Granta    9405
# generation      300889   1119                     I   62186
# engine_type     376094      5              GASOLINE  318690
# drive_type      376094      3       FORWARD_CONTROL  209438
# transmission    376094      4             AUTOMATIC  152243
# availability    376088      3              IN_STOCK  364037
# color           376094     16                040001   82888
# car_type        376094      2                  used  331394
# condition       376094      1          CONDITION_OK  376094
# region          376094   3841                Москва   73260
# car_class       374802      9                     C  105513
# body_type       376094    262     Внедорожник 5 дв.  147068
# steering_wheel  376094      2                  LEFT  350070
# vendor          376094      7              EUROPEAN  101957
# ...

# %%
df.brand.unique()
# Out:
# array(['LADA (ВАЗ)', 'Москвич', 'OMODA', 'Nissan', 'Mercedes-Benz',
#        'Honda', 'Chevrolet', 'Mitsubishi', 'Peugeot', 'Kia', 'ГАЗ',
#        'Suzuki', 'Datsun', 'Citroen', 'Toyota', 'Audi', 'BMW', 'Ford',
#        'Mazda', 'Volvo', 'УАЗ', 'Acura', 'Opel', 'Volkswagen', 'Hyundai',
#        'ИЖ', 'Lifan', 'JAC', 'SsangYong', 'Daewoo', 'Buick', 'Geely',
#        'Land Rover', 'Subaru', 'MINI', 'Hummer', 'Skoda', 'Jeep',
#        'Chrysler', 'Great Wall', 'Tesla', 'Renault', 'Alfa Romeo', 'ЗАЗ',
#        'Chery', 'Rover', 'Changan', 'Haval', 'Lotus', 'EXEED', 'Infiniti',
#        'GAC', 'BAIC', 'Tank', 'Lexus', 'RAM', 'Polestar', 'Vortex',
#        'LiXiang', 'SEAT', 'Jaguar', 'Porsche', 'Livan', 'Cadillac',
#        'Haima', 'Dodge', 'Kaiyi', 'Zeekr', 'Ravon', 'BYD', 'Zotye', 'FAW',
#        'Daihatsu', 'TATA', 'Voyah', 'Dacia', 'Lamborghini', 'ТагАЗ',
#        'Isuzu', 'DongFeng', 'Renault Samsung', 'ЛуАЗ', 'Bentley',
# ...

# %%
df.engine_type.unique()
# Out:
# array(['GASOLINE', 'DIESEL', 'HYBRID', 'ELECTRO', 'LPG'], dtype=object)

# %%
df.drive_type.unique()
# Out:
# array(['FORWARD_CONTROL', 'ALL_WHEEL_DRIVE', 'REAR_DRIVE'], dtype=object)

# %%
df.transmission.unique()
# Out:
# array(['MECHANICAL', 'ROBOT', 'AUTOMATIC', 'VARIATOR'], dtype=object)

# %%
df.car_class.unique()
# Out:
# array(['B', 'C', 'E', 'D', 'S', nan, 'M', 'J', 'A', 'F'], dtype=object)

# %%
df.vendor.unique()
# Out:
# array(['RUSSIAN', 'CHINESE', 'JAPANESE', 'VENDOR_UNKNOWN', 'AMERICAN',
#        'EUROPEAN', 'KOREAN'], dtype=object)

# %%
df.price_segment.unique()
# Out:
# array(['ECONOMY', 'MEDIUM', 'PREMIUM'], dtype=object)

# %% [markdown]
# # Model border

# %%
df.groupby(['brand', 'model', 'generation']).size().sort_values(ascending=False)
# Out:
# brand            model                             generation
# LADA (ВАЗ)       Granta                            I Рестайлинг                       6512
#                  Priora                            I                                  3915
#                  Vesta                             I                                  3404
#                  2121 (4x4)                        I Рестайлинг                       3071
# Haval            Jolion                            I                                  2960
# LADA (ВАЗ)       Granta                            I                                  2893
#                  Kalina                            I                                  2627
# EXEED            TXL                               I Рестайлинг                       2442
# LADA (ВАЗ)       Niva                              I Рестайлинг (Travel)              1887
# Chevrolet        Niva                              I Рестайлинг                       1628
# ...

# %% [markdown]
# ### Только китайские вендоры

# %%
df.query('vendor == "CHINESE"').groupby(['brand', 'model', 'generation']).size().sort_values(ascending=False)
# Out:
# brand       model             generation
# Haval       Jolion            I                      2960
# EXEED       TXL               I Рестайлинг           2442
# Haval       F7                I Рестайлинг           1480
# Chery       Tiggo 8 Pro       I                      1332
# EXEED       VX                I                      1110
# Haval       F7x               I Рестайлинг           1073
# Geely       Coolray           I                      1036
#             Tugella           I Рестайлинг            925
# Changan     CS35PLUS          I Рестайлинг            814
#             CS55PLUS          I Рестайлинг            666
# Chery       Tiggo 7 Pro       I                       629
#             Tiggo 8           I Рестайлинг            629
# JAC         J7                I                       481
# Mazda       CX-4              I Рестайлинг            481
# Haval       H9                I Рестайлинг            407
# ...

# %% [markdown]
# ## Без дубликатов

# %%
df_wd.groupby(['brand', 'model', 'generation']).size().sort_values(ascending=False)
# Out:
# brand            model                             generation
# LADA (ВАЗ)       Granta                            I Рестайлинг                       5535
#                  Priora                            I                                  3875
#                  Granta                            I                                  2893
#                  Priora                            I Рестайлинг                       1178
#                  Kalina                            II                                   39
# BMW              X7                                I (G07) Рестайлинг                   39
# Lexus            LX                                IV                                   39
# Volkswagen       Tiguan                            I                                    39
# Hyundai          Palisade                          I Рестайлинг                         38
# Mercedes-Benz    S-Класс                           IV (W220) Рестайлинг                 38
# ...

# %%
df_wd.query('vendor == "CHINESE"').groupby(['brand', 'model', 'generation']).size().sort_values(ascending=False)
# Out:
# brand       model             generation
# Changan     CS35PLUS          I                      38
# Kia         Sportage (China)  III (NP) Рестайлинг    38
# GAC         GS8               II                     37
# Chery       Tiggo (T11)       I                      37
#                               I Рестайлинг (FL)      37
# Great Wall  Poer              I                      37
#             Hover H3          I                      37
# Geely       Tugella           I Рестайлинг           37
# Chery       Tiggo 4           I Рестайлинг           37
# Geely       Tugella           I                      37
#             MK Cross          I                      37
#             MK                I                      37
# Chery       Tiggo 7 Pro       I                      37
#             IndiS (S18D)      I                      37
#             Tiggo 8           I                      37
#                               I Рестайлинг           37
# ...
